# %%
###importamos librerias
import pandas as pd

# %%
###mandamos a llamar el dataframe y meidante la funcion de read_Excel, indicamos la ruta del archivo que deseamos leer

df2 = pd.read_excel("../docs/Programas de Universidades.xls")
df2.head()
# Out:
#   CODIGO_ENTIDAD                                    NOMBRE TIPO_GESTION
# 0            065   UNIVERSIDAD TECNOLÓGICA DEL PERÚ S.A.C.      PRIVADO  \
# 1            008  PONTIFICIA UNIVERSIDAD CATÓLICA DEL PERÚ      PRIVADO
# 2            065   UNIVERSIDAD TECNOLÓGICA DEL PERÚ S.A.C.      PRIVADO
# 3           052A          UNIVERSIDAD CÉSAR VALLEJO S.A.C.      PRIVADO
# 4            065   UNIVERSIDAD TECNOLÓGICA DEL PERÚ S.A.C.      PRIVADO
#
#   ESTADO_LICENCIAMIENTO  PERIODO_LICENCIAMIENTO CODIGO_FILIAL   NOMBRE_FILIAL
# 0     LICENCIA OTORGADA                       6             S        UTP-LIMA  \
# 1     LICENCIA OTORGADA                      10             S       PUCP-LIMA
# 2     LICENCIA OTORGADA                       6             S        UTP-LIMA
# 3     LICENCIA OTORGADA                       6           F01      UPCV-PIURA
# 4     LICENCIA OTORGADA                       6           F02  UTP-LAMBAYEQUE
#
# ...
